# %% [markdown]
# ##### FT VITS

# %%
# %cd ..
import os
os.getcwd()
# Out:
# /home/is/lathifgalih-k/research_naist/multimodal-clone
# /home/is/lathifgalih-k/miniconda3/envs/myenv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# '/home/is/lathifgalih-k/research_naist/multimodal-clone'

# %%
# This will automatically resume from the latest checkpoint in als_finetune_v1
# !python vits/train_ms.py -c vits/configs/vctk_base.json -m vits/als_finetune_v1
# Out:
# /home/is/lathifgalih-k/miniconda3/envs/myenv/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# /home/is/lathifgalih-k/research_naist/multimodal-clone/vits/train_ms.py:114: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=hps.train.fp16_run)
# /home/is/lathifgalih-k/research_naist/multimodal-clone/vits/utils.py:138: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampling_rate, data = read(full_path)
# /home/is/lathifgalih-k/research_naist/multimodal-clone/vits/utils.py:138: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sampling_rate, data = read(full_path)
# ...
