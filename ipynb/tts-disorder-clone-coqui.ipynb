# %%
import os
os.getcwd()
# %cd ../clone-voice-coqui/
# Out:
# /home/is/lathifgalih-k/research_naist/multimodal-clone/clone-voice-coqui

# %%
import sys
print(sys.executable)
# Out:
# /home/is/lathifgalih-k/miniconda3/envs/yourtts/bin/python

# %% [markdown]
# ## ALS Dataset

# %% [markdown]
# ### XTTS2

# %%
# Experiment Generate for audio in input audio
import os
import torch
from TTS.api import TTS

# Inisialisasi TTS
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to("cuda" if torch.cuda.is_available() else "cpu")   

# Path ke direktori input audio
input_audio = "/home/is/lathifgalih-k/research_naist/multimodal-clone/dataset-toronto/ALS/Input_Audios/A002/input_A002_02_BBP_NORMAL_segment_0.wav"
output_dir = "exp/XTTSv2/"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

output_file = os.path.join(output_dir, f"A002_BBP_cloned.wav")

# Jalankan TTS untuk setiap file audio
tts.tts_to_file(
    text="Buy Bobby a puppy",
    speaker_wav=input_audio,
    language="en",
    file_path=output_file
)
print(f"✅ Audio untuk A002_BBP berhasil disimpan di '{output_file}'")
# Out:
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
#  > Using model: xtts
# /home/is/lathifgalih-k/miniconda3/envs/yourtts/lib/python3.10/site-packages/TTS/utils/io.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location, **kwargs)
#  > Text splitted to sentences.
# ['Buy Bobby a puppy']
#  > Processing time: 1.684110403060913
#  > Real-time factor: 0.5754809445123533
# ✅ Audio untuk A002_BBP berhasil disimpan di 'exp/XTTSv2/A002_BBP_cloned.wav'

# %%
# Generate for audio in input audio
import os
import torch
from TTS.api import TTS

# Inisialisasi TTS
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to("cuda" if torch.cuda.is_available() else "cpu")   

# Path ke direktori input audio
input_audio_dir = "/home/is/lathifgalih-k/research_naist/multimodal-clone/dataset-toronto/ALS/Input_Audios/"
output_dir = "output_audio/XTTSv2/"
# Out:
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
# /home/is/lathifgalih-k/miniconda3/envs/yourtts/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /home/is/lathifgalih-k/miniconda3/envs/yourtts/lib/python3.10/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
#  > Using model: xtts
# /home/is/lathifgalih-k/miniconda3/envs/yourtts/lib/python3.10/site-packages/TTS/utils/io.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location, **kwargs)

# %%
# Loop melalui setiap file audio di direktori input
for speaker in os.listdir(input_audio_dir):
    speaker_path = os.path.join(input_audio_dir, speaker)
    if os.path.isdir(speaker_path):
        i = 0
        for audio_file in os.listdir(speaker_path):
            if i >= 1:
                continue
            
            # Kondisi berbeda untuk A015 dan speaker lainnya
            if speaker == "A015":
                # Untuk A015, gunakan file dengan "pataka" dan "segment_0"
                if "pataka" in audio_file.lower() and "segment_0" in audio_file.lower() and audio_file.endswith(".wav"):
                    i += 1  # Hanya proses 1 file per speaker
                    input_audio_path = os.path.join(speaker_path, audio_file)
                    output_file = os.path.join(output_dir, f"{speaker}_cloned.wav")

                    # Jalankan TTS untuk setiap file audio
                    tts.tts_to_file(
                        text="Even for a British Open, this is different",
                        speaker_wav=input_audio_path,
                        language="en",
                        file_path=output_file
                    )
                    print(f"✅ Audio untuk {speaker}/{audio_file} berhasil disimpan di '{output_file}'")
            else:
                # Untuk speaker selain A015, gunakan file dengan "normal" dan "segment_0"
                if "normal" in audio_file.lower() and "segment_0" in audio_file.lower() and audio_file.endswith(".wav"):
                    i += 1  # Hanya proses 1 file per speaker
                    input_audio_path = os.path.join(speaker_path, audio_file)
                    output_file = os.path.join(output_dir, f"{speaker}_cloned.wav")

                    # Jalankan TTS untuk setiap file audio
                    tts.tts_to_file(
                        text="Even for a British Open, this is different",
                        speaker_wav=input_audio_path,
                        language="en",
                        file_path=output_file
                    )
                    print(f"✅ Audio untuk {speaker}/{audio_file} berhasil disimpan di '{output_file}'")
# Out:
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 28.65127158164978
#  > Real-time factor: 4.398466486405381
# ✅ Audio untuk A017/input_A017_02_BBP_Normal_segment_0.wav berhasil disimpan di 'output_audio/XTTSv2/A017_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 1.5421810150146484
#  > Real-time factor: 0.3025364001874822
# ✅ Audio untuk A010/input_A010_02_BBP_NORMAL_segment_0.wav berhasil disimpan di 'output_audio/XTTSv2/A010_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 1.577996015548706
#  > Real-time factor: 0.3723122340229516
# ✅ Audio untuk A014/input_A014_02_BBP_Normal_segment_0.wav berhasil disimpan di 'output_audio/XTTSv2/A014_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 1.300628900527954
#  > Real-time factor: 0.3182015273460122
# ✅ Audio untuk A011/input_A011_02_BBP_NORMAL_segment_0.wav berhasil disimpan di 'output_audio/XTTSv2/A011_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 1.446509838104248
#  > Real-time factor: 0.32189106582228594
# ✅ Audio untuk A008/input_A008_02_BBP_NORMAL_segment_0.wav berhasil disimpan di 'output_audio/XTTSv2/A008_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 1.7789912223815918
#  > Real-time factor: 0.3562959276768829
# ✅ Audio untuk A002/input_A002_02_BBP_NORMAL_segment_0.wav berhasil disimpan di 'output_audio/XTTSv2/A002_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 1.260784387588501
#  > Real-time factor: 0.36804034826210613
# ✅ Audio untuk A016/input_A016_02_BBP_Normal_segment_0.wav berhasil disimpan di 'output_audio/XTTSv2/A016_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 2.1012301445007324
#  > Real-time factor: 0.44791303834339863
# ✅ Audio untuk A006/input_A006_02_BBP_NORMAL_al_segment_0.wav berhasil disimpan di 'output_audio/XTTSv2/A006_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 1.2350265979766846
#  > Real-time factor: 0.3605212942886292
# ✅ Audio untuk A015/input_A015_02_DDK_PATAKA_segment_0.wav berhasil disimpan di 'output_audio/XTTSv2/A015_cloned.wav'

# %% [markdown]
# ### YourTTS

# %%
# Experiment Generate for audio in input audio
import os
import torch
from TTS.api import TTS

# Inisialisasi TTS
tts = TTS("tts_models/multilingual/multi-dataset/your_tts").to("cuda" if torch.cuda.is_available() else "cpu")   

# Path ke direktori input audio
input_audio = "/home/is/lathifgalih-k/research_naist/multimodal-clone/dataset-toronto/ALS/Input_Audios/A002/input_A002_02_BBP_NORMAL_segment_0.wav"
output_dir = "exp/YourTTS/"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

output_file = os.path.join(output_dir, f"A002_BBP_cloned.wav")

# Jalankan TTS untuk setiap file audio
tts.tts_to_file(
    text="Buy Bobby a puppy",
    speaker_wav=input_audio,
    language="en",
    file_path=output_file
)
print(f"✅ Audio untuk A002_BBP berhasil disimpan di '{output_file}'")
# Out:
#  > tts_models/multilingual/multi-dataset/your_tts is already downloaded.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
# /home/is/lathifgalih-k/miniconda3/envs/yourtts/lib/python3.10/site-packages/TTS/utils/io.py:54: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location, **kwargs)
#  > Model fully restored.
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:64
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:512
#  | > power:1.5
#  | > preemphasis:0.97
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:False
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:False
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:True
#  | > db_level:-27.0
#  | > stats_path:None
#  | > base:10
#  | > hop_length:160
#  | > win_length:400
#  > External Speaker Encoder Loaded !!
#  > initialization of language-embedding layers.
#  > Model fully restored.
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:64
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:512
#  | > power:1.5
#  | > preemphasis:0.97
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:False
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:False
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:True
#  | > db_level:-27.0
#  | > stats_path:None
#  | > base:10
#  | > hop_length:160
#  | > win_length:400
#  > Text splitted to sentences.
# ['Buy Bobby a puppy']
#  > Processing time: 4.8125622272491455
#  > Real-time factor: 2.3126200034834916
# ✅ Audio untuk A002_BBP berhasil disimpan di 'exp/YourTTS/A002_BBP_cloned.wav'

# %%
# Generate for audio in input audio
import os
import torch
from TTS.api import TTS

# Inisialisasi TTS
tts = TTS("tts_models/multilingual/multi-dataset/your_tts").to("cuda" if torch.cuda.is_available() else "cpu")   

# Path ke direktori input audio
input_audio_dir = "/home/is/lathifgalih-k/research_naist/multimodal-clone/dataset-toronto/ALS/Input_Audios/"
output_dir = "output_audio/YourTTS/"
# Out:
#  > tts_models/multilingual/multi-dataset/your_tts is already downloaded.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Model fully restored.
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:64
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:512
#  | > power:1.5
#  | > preemphasis:0.97
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:False
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:False
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:True
#  | > db_level:-27.0
#  | > stats_path:None
#  | > base:10
#  | > hop_length:160
#  | > win_length:400
#  > External Speaker Encoder Loaded !!
#  > initialization of language-embedding layers.
#  > Model fully restored.
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:64
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:512
#  | > power:1.5
#  | > preemphasis:0.97
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:False
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:False
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:True
#  | > db_level:-27.0
#  | > stats_path:None
#  | > base:10
#  | > hop_length:160
#  | > win_length:400

# %%
# Loop melalui setiap file audio di direktori input
for speaker in os.listdir(input_audio_dir):
    speaker_path = os.path.join(input_audio_dir, speaker)
    if os.path.isdir(speaker_path):
        i = 0
        for audio_file in os.listdir(speaker_path):
            if i >= 1:
                continue
            
            # Kondisi berbeda untuk A015 dan speaker lainnya
            if speaker == "A015":
                # Untuk A015, gunakan file dengan "pataka" dan "segment_0"
                if "pataka" in audio_file.lower() and "segment_0" in audio_file.lower() and audio_file.endswith(".wav"):
                    i += 1  # Hanya proses 1 file per speaker
                    input_audio_path = os.path.join(speaker_path, audio_file)
                    output_file = os.path.join(output_dir, f"{speaker}_cloned.wav")

                    # Jalankan TTS untuk setiap file audio
                    tts.tts_to_file(
                        text="Even for a British Open, this is different",
                        speaker_wav=input_audio_path,
                        language="en",
                        file_path=output_file
                    )
                    print(f"✅ Audio untuk {speaker}/{audio_file} berhasil disimpan di '{output_file}'")
            else:
                # Untuk speaker selain A015, gunakan file dengan "normal" dan "segment_0"
                if "normal" in audio_file.lower() and "segment_0" in audio_file.lower() and audio_file.endswith(".wav"):
                    i += 1  # Hanya proses 1 file per speaker
                    input_audio_path = os.path.join(speaker_path, audio_file)
                    output_file = os.path.join(output_dir, f"{speaker}_cloned.wav")

                    # Jalankan TTS untuk setiap file audio
                    tts.tts_to_file(
                        text="Even for a British Open, this is different",
                        speaker_wav=input_audio_path,
                        language="en",
                        file_path=output_file
                    )
                    print(f"✅ Audio untuk {speaker}/{audio_file} berhasil disimpan di '{output_file}'")
# Out:
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 13.130438566207886
#  > Real-time factor: 3.4327943963942182
# ✅ Audio untuk A017/input_A017_02_BBP_Normal_segment_0.wav berhasil disimpan di 'output_audio/YourTTS/A017_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 0.39151573181152344
#  > Real-time factor: 0.12807187825041658
# ✅ Audio untuk A010/input_A010_02_BBP_NORMAL_segment_0.wav berhasil disimpan di 'output_audio/YourTTS/A010_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 0.7413086891174316
#  > Real-time factor: 0.23631134495295877
# ✅ Audio untuk A014/input_A014_02_BBP_Normal_segment_0.wav berhasil disimpan di 'output_audio/YourTTS/A014_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 0.28565549850463867
#  > Real-time factor: 0.0800379653977693
# ✅ Audio untuk A011/input_A011_02_BBP_NORMAL_segment_0.wav berhasil disimpan di 'output_audio/YourTTS/A011_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 0.5121932029724121
#  > Real-time factor: 0.14885010257844003
# ✅ Audio untuk A008/input_A008_02_BBP_NORMAL_segment_0.wav berhasil disimpan di 'output_audio/YourTTS/A008_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 0.29740405082702637
#  > Real-time factor: 0.10380595142304584
# ✅ Audio untuk A002/input_A002_02_BBP_NORMAL_segment_0.wav berhasil disimpan di 'output_audio/YourTTS/A002_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 0.27271008491516113
#  > Real-time factor: 0.06129693974267501
# ✅ Audio untuk A016/input_A016_02_BBP_Normal_segment_0.wav berhasil disimpan di 'output_audio/YourTTS/A016_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 0.2851560115814209
#  > Real-time factor: 0.08524843395558172
# ✅ Audio untuk A006/input_A006_02_BBP_NORMAL_al_segment_0.wav berhasil disimpan di 'output_audio/YourTTS/A006_cloned.wav'
#  > Text splitted to sentences.
# ['Even for a British Open, this is different']
#  > Processing time: 0.8874859809875488
#  > Real-time factor: 0.1912273176012818
# ✅ Audio untuk A015/input_A015_02_DDK_PATAKA_segment_0.wav berhasil disimpan di 'output_audio/YourTTS/A015_cloned.wav'

# %% [markdown]
# #### Evaluasi On Cosine Similarity Speaker Embedding

# %% [markdown]
# ## Stroke

# %% [markdown]
# ### XTTSv2

# %%
# Experiment Generate for audio in input audio
import os
import torch
from TTS.api import TTS

# Inisialisasi TTS
tts = TTS("tts_models/multilingual/multi-dataset/your_tts").to("cuda" if torch.cuda.is_available() else "cpu")   

# Path ke direktori input audio
input_audio = "/home/is/lathifgalih-k/research_naist/multimodal-clone/vits/dataset-toronto/Stroke/Input_Audios/S003/input_S003_02_BBP_NORMAL_segment_1.wav"
output_dir = "exp/Stroke/YourTTS/"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

output_file = os.path.join(output_dir, f"S003_BBP_cloned.wav")

# Jalankan TTS untuk setiap file audio
tts.tts_to_file(
    text="Buy Bobby a puppy",
    speaker_wav=input_audio,
    language="en",
    file_path=output_file
)
print(f"✅ Audio untuk S003_BBP berhasil disimpan di '{output_file}'")
# Out:
#  > tts_models/multilingual/multi-dataset/your_tts is already downloaded.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Model fully restored.
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:64
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:512
#  | > power:1.5
#  | > preemphasis:0.97
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:False
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:False
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:True
#  | > db_level:-27.0
#  | > stats_path:None
#  | > base:10
#  | > hop_length:160
#  | > win_length:400
#  > External Speaker Encoder Loaded !!
#  > initialization of language-embedding layers.
#  > Model fully restored.
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:64
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:512
#  | > power:1.5
#  | > preemphasis:0.97
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:False
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:False
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:True
#  | > db_level:-27.0
#  | > stats_path:None
#  | > base:10
#  | > hop_length:160
#  | > win_length:400
#  > Text splitted to sentences.
# ['Buy Bobby a puppy']
#  > Processing time: 0.37137413024902344
#  > Real-time factor: 0.18124652525574594
# ✅ Audio untuk S003_BBP berhasil disimpan di 'exp/Stroke/YourTTS/S003_BBP_cloned.wav'

# %% [markdown]
# ### YourTTS

# %%
# Experiment Generate for audio in input audio
import os
import torch
from TTS.api import TTS

# Inisialisasi TTS
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2").to("cuda" if torch.cuda.is_available() else "cpu")   

# Path ke direktori input audio
input_audio = "/home/is/lathifgalih-k/research_naist/multimodal-clone/vits/dataset-toronto/Stroke/Input_Audios/S003/input_S003_02_BBP_NORMAL_segment_1.wav"
output_dir = "exp/Stroke/XTTSv2/"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

output_file = os.path.join(output_dir, f"S003_BBP_cloned.wav")

# Jalankan TTS untuk setiap file audio
tts.tts_to_file(
    text="Buy Bobby a puppy",
    speaker_wav=input_audio,
    language="en",
    file_path=output_file
)
print(f"✅ Audio untuk S003_BBP berhasil disimpan di '{output_file}'")

# %% [markdown]
# ### Evaluation By Cosine Similarity of Speaker Embedding

# %%
# ALS
from resemblyzer import VoiceEncoder, preprocess_wav
from pathlib import Path
import numpy as np
from scipy.spatial.distance import cosine

# Load audio files (pastikan formatnya .wav dan durasi minimal ~1 detik)
input_audio = "/home/is/lathifgalih-k/research_naist/multimodal-clone/dataset-toronto/ALS/Input_Audios/A002/input_A002_02_BBP_NORMAL_segment_0.wav"
original_audio = preprocess_wav(Path(input_audio))
cloned_audio = preprocess_wav(Path("/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-voice-coqui/exp/ALS/YourTTS/A002_BBP_cloned.wav"))

# Init encoder
encoder = VoiceEncoder()

# Extract embeddings (1 vector per utterance)
original_embed = encoder.embed_utterance(original_audio)
cloned_embed = encoder.embed_utterance(cloned_audio)

# Compute cosine similarity
cos_sim = 1 - cosine(original_embed, cloned_embed)

print(f"Cosine Similarity: {cos_sim:.4f}")
# Out:
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Cosine Similarity: 0.5996

# %%
# Stroke
from resemblyzer import VoiceEncoder, preprocess_wav
from pathlib import Path
import numpy as np
from scipy.spatial.distance import cosine

# Load audio files (pastikan formatnya .wav dan durasi minimal ~1 detik)
input_audio = "/home/is/lathifgalih-k/research_naist/multimodal-clone/vits/dataset-toronto/Stroke/Input_Audios/S003/input_S003_02_BBP_NORMAL_segment_1.wav"
original_audio = preprocess_wav(Path(input_audio))
cloned_audio = preprocess_wav(Path("/home/is/lathifgalih-k/research_naist/multimodal-clone/clone-voice-coqui/exp/Stroke/YourTTS/S003_BBP_cloned.wav"))

# Init encoder
encoder = VoiceEncoder()

# Extract embeddings (1 vector per utterance)
original_embed = encoder.embed_utterance(original_audio)
cloned_embed = encoder.embed_utterance(cloned_audio)

# Compute cosine similarity
cos_sim = 1 - cosine(original_embed, cloned_embed)

print(f"Cosine Similarity: {cos_sim:.4f}")
# Out:
# Loaded the voice encoder model on cuda in 0.03 seconds.
# Cosine Similarity: 0.6664
